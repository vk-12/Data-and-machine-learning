# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('train1.csv')
submisson = pd.read_csv('SubmissionSample.csv')

# %%
submisson.head()
# Out:
#    Loan.ID  Loan.Status
# 0        2          NaN
# 1        6          NaN
# 2        9          NaN
# 3       12          NaN
# 4       14          NaN

# %%
df.Term.value_counts()
# Out:
# Short Term    44184
# Long Term     16620
# Name: Term, dtype: int64

# %%
df.shape
# Out:
# (60804, 18)

# %%
df.replace('NA', np.NaN)
# Out:
#        Loan.ID  Current.Loan.Amount        Term  Credit.Score  \
# 0            0                17879  Short Term         739.0
# 1            1             99999999   Long Term         619.0
# 2            3             99999999  Short Term         738.0
# 3            4                11200  Short Term         738.0
# 4            5                 3608  Short Term         731.0
# ...        ...                  ...         ...           ...
# 60799    84184             99999999  Short Term         725.0
# 60800    84185                18229  Short Term         747.0
# 60801    84186                10165  Short Term           NaN
# 60802    84187             99999999  Short Term         744.0
# 60803    84189                 2866  Short Term         703.0
#
#       Years.in.current.job Home.Ownership  Annual.Income             Purpose  \
# 0                  6 years  Home Mortgage        95357.0  Debt Consolidation
# ...

# %%
df.rename(columns={"Loan.ID" : "LoanID", "Current.Loan.Amount" : "CurrentLoanAmount", "Credit.Score" : "CreditScore", "Years.in.current.job" : "Yearsincurrentjob","Home.Ownership" : "HomeOwnership", "Annual.Income" : "AnnualIncome", "Monthly.Debt" : "MonthlyDebt", "Years.of.Credit.History" : "YearsofCreditHistory"},inplace=True)

# %%
df.rename(columns={"Months.since.last.delinquent" : "Monthssincelastdelinquent", "Number.of.Open.Accounts" : "NumberofOpenAccounts", "Number.of.Credit.Problems" : "NumberofCreditProblems", "Current.Credit.Balance" : "CurrentCreditBalance", "Maximum.Open.Credit" : "MaximumOpenCredit", "Tax.Liens" : "TaxLiens", "Loan.Status" : "LoanStatus"},inplace=True)

# %%
df.head()
# Out:
#    LoanID  CurrentLoanAmount        Term  CreditScore  Yearsincurrentjob  \
# 0       0              17879  Short Term        739.0            6 years
# 1       1           99999999   Long Term        619.0            6 years
# 2       3           99999999  Short Term        738.0  less than  1 year
# 3       4              11200  Short Term        738.0            4 years
# 4       5               3608  Short Term        731.0          10+ years
#
#    HomeOwnership  AnnualIncome             Purpose  MonthlyDebt  \
# 0  Home Mortgage       95357.0  Debt Consolidation      1509.82
# 1           Rent       54406.0  Debt Consolidation      1065.45
# 2           Rent       40480.0       Medical Bills       573.47
# 3           Rent       53965.0  Debt Consolidation      1358.11
# 4  Home Mortgage       47709.0   Home Improvements       339.93
#
#    YearsofCreditHistory  Monthssincelastdelinquent  NumberofOpenAccounts  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
df['term'] = LabelEncoder().fit_transform(df.Term)
df['homeownership'] = LabelEncoder().fit_transform(df.HomeOwnership)
df['purpose']=  LabelEncoder().fit_transform(df.Purpose)
df1 = df.drop(['Term','HomeOwnership','Purpose'], axis=1)
df1.head()
# Out:
#    LoanID  CurrentLoanAmount  CreditScore  Yearsincurrentjob  AnnualIncome  \
# 0       0              17879        739.0            6 years       95357.0
# 1       1           99999999        619.0            6 years       54406.0
# 2       3           99999999        738.0  less than  1 year       40480.0
# 3       4              11200        738.0            4 years       53965.0
# 4       5               3608        731.0          10+ years       47709.0
#
#    MonthlyDebt  YearsofCreditHistory  Monthssincelastdelinquent  \
# 0      1509.82                  34.4                        5.0
# 1      1065.45                  12.7                        NaN
# 2       573.47                  32.7                       60.0
# 3      1358.11                  15.8                        NaN
# 4       339.93                  16.1                       47.0
#
#    NumberofOpenAccounts  NumberofCreditProblems  CurrentCreditBalance  \
# ...

# %%
df.Yearsincurrentjob.value_counts()
df['Yearsincurrentjob'] = LabelEncoder().fit_transform(df.Yearsincurrentjob)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode(values, uniques, encode, check_unknown)
#     111         try:
# --> 112             res = _encode_python(values, uniques, encode)
#     113         except TypeError:
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode_python(values, uniques, encode)
#      59     if uniques is None:
# ---> 60         uniques = sorted(set(values))
#      61         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-316-2bcbe379d643> in <module>
#       1 df.Yearsincurrentjob.value_counts()
# ...

# %% [markdown]
# df1.head()

# %%
print(df['Yearsincurrentjob'].value_counts().count())
# Out:
# 11

# %%
print(df['Yearsincurrentjob'].value_counts())
# Out:
# 10+ years            18810
# 2 years               5539
# 3 years               5048
# less than  1 year     4996
# 5 years               4150
# 1 year                3901
# 4 years               3754
# 6 years               3532
# 7 years               3313
# 8 years               2831
# 9 years               2401
# Name: Yearsincurrentjob, dtype: int64

# %%
dfw = df['Yearsincurrentjob']
dfw.value_counts()
# Out:
# 10+ years            18810
# 2 years               5539
# 3 years               5048
# less than  1 year     4996
# 5 years               4150
# 1 year                3901
# 4 years               3754
# 6 years               3532
# 7 years               3313
# 8 years               2831
# 9 years               2401
# Name: Yearsincurrentjob, dtype: int64

# %%
df.drop('Yearsincurrentjobo',inplace=True,axis=1)

# %%
df['Yearsincurrentjob']. astype(object). astype(str)
# Out:
# 0                  6 years
# 1                  6 years
# 2        less than  1 year
# 3                  4 years
# 4                10+ years
#                ...
# 60799              3 years
# 60800              3 years
# 60801              5 years
# 60802              9 years
# 60803              8 years
# Name: Yearsincurrentjob, Length: 60804, dtype: object

# %%
df['Yearsincurrentjob'] = df['Yearsincurrentjob'].astype('str')

# %%
df['Yearsincurrentjob'].describe
# Out:
# <bound method NDFrame.describe of 0                  6 years
# 1                  6 years
# 2        less than  1 year
# 3                  4 years
# 4                10+ years
#                ...
# 60799              3 years
# 60800              3 years
# 60801              5 years
# 60802              9 years
# 60803              8 years
# Name: Yearsincurrentjob, Length: 60804, dtype: object>

# %%
from sklearn.preprocessing import LabelEncoder
a= df.Yearsincurrentjob
le = LabelEncoder()
df['Yearsincurrentjob0'] =le.fit_transform(a)

# %%
df.Yearsincurrentjob0.value_counts()
# Out:
# 1     18810
# 2      5539
# 3      5048
# 10     4996
# 5      4150
# 0      3901
# 4      3754
# 6      3532
# 7      3313
# 8      2831
# 11     2529
# 9      2401
# Name: Yearsincurrentjob0, dtype: int64

# %%
df.Yearsincurrentjob.value_counts()
# Out:
# 10+ years            18810
# 2 years               5539
# 3 years               5048
# less than  1 year     4996
# 5 years               4150
# 1 year                3901
# 4 years               3754
# 6 years               3532
# 7 years               3313
# 8 years               2831
# nan                   2529
# 9 years               2401
# Name: Yearsincurrentjob, dtype: int64

# %%
df.head()
# Out:
#    LoanID  CurrentLoanAmount        Term  CreditScore  Yearsincurrentjob  \
# 0       0              17879  Short Term        739.0            6 years
# 1       1           99999999   Long Term        619.0            6 years
# 2       3           99999999  Short Term        738.0  less than  1 year
# 3       4              11200  Short Term        738.0            4 years
# 4       5               3608  Short Term        731.0          10+ years
#
#    HomeOwnership  AnnualIncome             Purpose  MonthlyDebt  \
# 0  Home Mortgage       95357.0  Debt Consolidation      1509.82
# 1           Rent       54406.0  Debt Consolidation      1065.45
# 2           Rent       40480.0       Medical Bills       573.47
# 3           Rent       53965.0  Debt Consolidation      1358.11
# 4  Home Mortgage       47709.0   Home Improvements       339.93
#
#    YearsofCreditHistory  Monthssincelastdelinquent  NumberofOpenAccounts  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
dfn.head()
# Out:
#    NumberofCreditProblems  CurrentCreditBalance  MaximumOpenCredit  \
# 0                       0                 23986              40313
# 1                       0                 22938              31250
# 2                       1                  3963               5669
# 3                       1                 11782              25951
# 4                       0                 22909              25568
#
#    Bankruptcies  TaxLiens  LoanStatus  term  homeownership  purpose  \
# 0             0         0           1     1              1        3
# 1             0         0           1     0              3        3
# 2             1         0           1     1              3        6
# 3             1         0           1     1              3        3
# 4             0         0           1     1              1        5
#
#    Yearsincurrentjob0  Yearsincurrentjobf
# 0                   6                   7
# 1                   6                   7
# ...

# %%
dfn = df.drop(['Term','Yearsincurrentjob', 'HomeOwnership','Purpose'],axis=1)

# %%
df.Yearsincurrentjob.isnull().sum()
# Out:
# 0

# %%
mean = dfn['CreditScore'].mean()
dfn['CreditScore']=dfn['CreditScore'].fillna(mean)

# %%
mean = dfn['AnnualIncome'].mean()
dfn['AnnualIncome']=dfn['AnnualIncome'].fillna(mean)

# %%
mean = dfn['Monthssincelastdelinquent'].mean()
dfn['Monthssincelastdelinquent']=dfn['Monthssincelastdelinquent'].fillna(mean)

# %%
mean = dfn['Bankruptcies'].mean()
dfn['Bankruptcies']=dfn['Bankruptcies'].fillna(mean)

# %%
mean = dfn['TaxLiens'].mean()
dfn['TaxLiens']=dfn['TaxLiens'].fillna(mean)

# %%
df['Yearsincurrentjob1']=df.Yearsincurrentjob0.replace('11', np.nan)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-325-b1c590149e8f> in <module>
# ----> 1 df['Yearsincurrentjob1']=df.Yearsincurrentjob0.replace('11', np.nan)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Yearsincurrentjob0'

# %%
df.Yearsincurrentjob0.unique()
# Out:
# array([ 6, 10,  4,  1,  5,  3,  8,  0,  2,  9,  7, 11])

# %%
df['Yearsincurrentjob3']= df.Yearsincurrentjob0.replace(to_replace ="11", 
                 value ="80")

# %%
df.Yearsincurrentjob3.unique()
# Out:
# array([ 6, 10,  4,  1,  5,  3,  8,  0,  2,  9,  7, 11])

# %%
df.Yearsincurrentjob3.replace('11', np.nan, inplace=True)

# %%
map = {'10+ years' : 11,
       '9 years' : 10,
       '8 years' : 9,
       '7 years' : 8,
       '6 years' : 7,
       '5 years' : 6,
       '4 years' : 5,
       '3 years' : 4,
       '2 years' : 3,
       '1 years' : 2,
       'less than  1 year' : 1
    
}
dfn['Yearsincurrentjobf'] = df.Yearsincurrentjob.map(map)

# %%
dfn.head()
# Out:
#    LoanID  CurrentLoanAmount  CreditScore  AnnualIncome  MonthlyDebt  \
# 0       0              17879        739.0       95357.0      1509.82
# 1       1           99999999        619.0       54406.0      1065.45
# 2       3           99999999        738.0       40480.0       573.47
# 3       4              11200        738.0       53965.0      1358.11
# 4       5               3608        731.0       47709.0       339.93
#
#    YearsofCreditHistory  Monthssincelastdelinquent  NumberofOpenAccounts  \
# 0                  34.4                   5.000000                    26
# 1                  12.7                  34.859402                     8
# 2                  32.7                  60.000000                     9
# 3                  15.8                  34.859402                     8
# 4                  16.1                  47.000000                     6
#
#    NumberofCreditProblems  CurrentCreditBalance  MaximumOpenCredit  \
# ...

# %%
df.drop(['t','Yearsincurrentjob0','Yearsincurrentjob1','Yearsincurrentjob3'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    LoanID  CurrentLoanAmount        Term  CreditScore  Yearsincurrentjob  \
# 0       0              17879  Short Term        739.0            6 years
# 1       1           99999999   Long Term        619.0            6 years
# 2       3           99999999  Short Term        738.0  less than  1 year
# 3       4              11200  Short Term        738.0            4 years
# 4       5               3608  Short Term        731.0          10+ years
#
#    HomeOwnership  AnnualIncome             Purpose  MonthlyDebt  \
# 0  Home Mortgage       95357.0  Debt Consolidation      1509.82
# 1           Rent       54406.0  Debt Consolidation      1065.45
# 2           Rent       40480.0       Medical Bills       573.47
# 3           Rent       53965.0  Debt Consolidation      1358.11
# 4  Home Mortgage       47709.0   Home Improvements       339.93
#
#    YearsofCreditHistory  Monthssincelastdelinquent  NumberofOpenAccounts  \
# ...

# %%
dfn.Yearsincurrentjobf.value_counts()
# Out:
# 11.0    18810
# 3.0      5539
# 4.0      5048
# 1.0      4996
# 6.0      4150
# 5.0      3754
# 7.0      3532
# 8.0      3313
# 9.0      2831
# 10.0     2401
# Name: Yearsincurrentjobf, dtype: int64

# %%
df.Yearsincurrentjobf.isna().sum()
# Out:
# 6430

# %%
meann = dfn.Yearsincurrentjobf.mean()
dfn['Yearsincurrentjobf']=dfn['Yearsincurrentjobf'].fillna(meann)

# %%
dfn.head()
# Out:
#    LoanID  CurrentLoanAmount  CreditScore  AnnualIncome  MonthlyDebt  \
# 0       0              17879        739.0       95357.0      1509.82
# 1       1           99999999        619.0       54406.0      1065.45
# 2       3           99999999        738.0       40480.0       573.47
# 3       4              11200        738.0       53965.0      1358.11
# 4       5               3608        731.0       47709.0       339.93
#
#    YearsofCreditHistory  Monthssincelastdelinquent  NumberofOpenAccounts  \
# 0                  34.4                   5.000000                    26
# 1                  12.7                  34.859402                     8
# 2                  32.7                  60.000000                     9
# 3                  15.8                  34.859402                     8
# 4                  16.1                  47.000000                     6
#
#    NumberofCreditProblems  CurrentCreditBalance  MaximumOpenCredit  \
# ...

# %%
dfn["YearsofCreditHistory"] = dfn["YearsofCreditHistory"].astype(int)
dfn["Monthssincelastdelinquent"] = dfn["Monthssincelastdelinquent"].astype(int)
dfn["Bankruptcies"] = dfn["Bankruptcies"].astype(int)
dfn["TaxLiens"] = dfn["TaxLiens"].astype(int)
dfn["Yearsincurrentjobf"] = dfn["Yearsincurrentjobf"].astype(int)
dfn["CreditScore"] = dfn["CreditScore"].astype(int)
dfn["AnnualIncome"] = dfn["AnnualIncome"].astype(int)
df["MonthlyDebt"] = dfn["MonthlyDebt"].astype(int)

# %%
q = dfn.drop(["LoanID","CurrentLoanAmount","CreditScore","AnnualIncome","MonthlyDebt","YearsofCreditHistory","Monthssincelastdelinquent","NumberofOpenAccounts"],axis=1)

# %%
dfn.head()
# Out:
#    LoanID  CurrentLoanAmount  CreditScore  AnnualIncome  MonthlyDebt  \
# 0       0              17879          739         95357      1509.82
# 1       1           99999999          619         54406      1065.45
# 2       3           99999999          738         40480       573.47
# 3       4              11200          738         53965      1358.11
# 4       5               3608          731         47709       339.93
#
#    YearsofCreditHistory  Monthssincelastdelinquent  NumberofOpenAccounts  \
# 0                    34                          5                    26
# 1                    12                         34                     8
# 2                    32                         60                     9
# 3                    15                         34                     8
# 4                    16                         47                     6
#
#    NumberofCreditProblems  CurrentCreditBalance  MaximumOpenCredit  \
# ...

# %%
df.head(12)
# Out:
#     LoanID  CurrentLoanAmount        Term  CreditScore  Yearsincurrentjob  \
# 0        0              17879  Short Term        739.0            6 years
# 1        1           99999999   Long Term        619.0            6 years
# 2        3           99999999  Short Term        738.0  less than  1 year
# 3        4              11200  Short Term        738.0            4 years
# 4        5               3608  Short Term        731.0          10+ years
# 5        7               7877  Short Term        738.0            5 years
# 6        8               4732   Long Term        701.0          10+ years
# 7       10               3469  Short Term        735.0            5 years
# 8       11              10031  Short Term        712.0            6 years
# 9       13              14073  Short Term          NaN            4 years
# 10      15              20044  Short Term        741.0            3 years
# 11      16              12473  Short Term          NaN          10+ years
#
# ...

# %%
q.head(5)
# Out:
#    NumberofCreditProblems  CurrentCreditBalance  MaximumOpenCredit  \
# 0                       0                 23986              40313
# 1                       0                 22938              31250
# 2                       1                  3963               5669
# 3                       1                 11782              25951
# 4                       0                 22909              25568
#
#    Bankruptcies  TaxLiens  LoanStatus  term  homeownership  purpose  \
# 0             0         0           1     1              1        3
# 1             0         0           1     0              3        3
# 2             1         0           1     1              3        6
# 3             1         0           1     1              3        3
# 4             0         0           1     1              1        5
#
#    Yearsincurrentjobf
# 0                   7
# 1                   7
# 2                   1
# 3                   5
# 4                  11

# %%
from sklearn import preprocessing
dfs = preprocessing.scale(dfn)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler = scaler.fit(dfn)
scaler
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
dfs = pd.DataFrame(scaler)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-358-fa105a7a75e7> in <module>
# ----> 1 dfs = pd.DataFrame(scaler)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     507                 )
#     508             else:
# --> 509                 raise ValueError("DataFrame constructor not properly called!")
#     510
#     511         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
dfr = preprocessing.normalize(dfn)

# %%
dfr
# Out:
# array([[0.00000000e+00, 1.65888625e-01, 6.85674221e-03, ...,
#         9.27840624e-06, 2.78352187e-05, 6.49488437e-05],
#        [9.99999787e-09, 9.99999777e-01, 6.18999868e-06, ...,
#         2.99999936e-08, 2.99999936e-08, 6.99999851e-08],
#        [2.99999978e-08, 9.99999916e-01, 7.37999945e-06, ...,
#         2.99999978e-08, 5.99999955e-08, 9.99999926e-09],
#        ...,
#        [7.36039393e-01, 8.88727393e-02, 9.65228767e-03, ...,
#         2.62290426e-05, 1.74860284e-05, 5.24580852e-05],
#        [8.41869668e-04, 9.99999595e-01, 7.43999706e-06, ...,
#         2.99999882e-08, 2.99999882e-08, 9.99999605e-08],
#        [8.85433095e-01, 3.01423137e-02, 7.39359614e-03, ...,
#         1.05172065e-05, 3.15516194e-05, 9.46548581e-05]])

# %%
from sklearn.preprocessing import MinMaxScaler
scaling = MinMaxScaler()
scaling.fit_transform(dfn)
# Out:
# array([[0.00000000e+00, 1.73880855e-04, 2.22382671e-02, ...,
#         3.33333333e-01, 2.00000000e-01, 6.00000000e-01],
#        [1.18780363e-05, 1.00000000e+00, 4.90974729e-03, ...,
#         1.00000000e+00, 2.00000000e-01, 6.00000000e-01],
#        [3.56341090e-05, 1.00000000e+00, 2.20938628e-02, ...,
#         1.00000000e+00, 4.00000000e-01, 0.00000000e+00],
#        ...,
#        [9.99964366e-01, 9.67404760e-05, 7.49458484e-02, ...,
#         1.00000000e+00, 1.33333333e-01, 5.00000000e-01],
#        [9.99976244e-01, 1.00000000e+00, 2.29602888e-02, ...,
#         1.00000000e+00, 2.00000000e-01, 9.00000000e-01],
#        [1.00000000e+00, 2.37501169e-05, 1.70397112e-02, ...,
#         3.33333333e-01, 2.00000000e-01, 8.00000000e-01]])

# %%
a
# Out:
# array([[0.00000000e+00, 1.73880855e-04, 2.22382671e-02, ...,
#         3.33333333e-01, 2.00000000e-01, 6.00000000e-01],
#        [1.18780363e-05, 1.00000000e+00, 4.90974729e-03, ...,
#         1.00000000e+00, 2.00000000e-01, 6.00000000e-01],
#        [3.56341090e-05, 1.00000000e+00, 2.20938628e-02, ...,
#         1.00000000e+00, 4.00000000e-01, 0.00000000e+00],
#        ...,
#        [9.99964366e-01, 9.67404760e-05, 7.49458484e-02, ...,
#         1.00000000e+00, 1.33333333e-01, 5.00000000e-01],
#        [9.99976244e-01, 1.00000000e+00, 2.29602888e-02, ...,
#         1.00000000e+00, 2.00000000e-01, 9.00000000e-01],
#        [1.00000000e+00, 2.37501169e-05, 1.70397112e-02, ...,
#         3.33333333e-01, 2.00000000e-01, 8.00000000e-01]])

# %%
 pd.DataFrame(data=a)
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.000000  0.000174  0.022238  0.010459  0.166631  0.543860  0.028409
# 1      0.000012  1.000000  0.004910  0.005757  0.117588  0.157895  0.193182
# 2      0.000036  1.000000  0.022094  0.004158  0.063291  0.508772  0.340909
# 3      0.000048  0.000107  0.022094  0.005706  0.149888  0.210526  0.193182
# 4      0.000059  0.000031  0.021083  0.004988  0.037516  0.228070  0.267045
# ...         ...       ...       ...       ...       ...       ...       ...
# 60799  0.999941  1.000000  0.020217  0.005548  0.014219  0.192982  0.119318
# 60800  0.999952  0.000177  0.023394  0.009975  0.086340  0.263158  0.079545
# 60801  0.999964  0.000097  0.074946  0.007837  0.017265  0.087719  0.193182
# 60802  0.999976  1.000000  0.022960  0.003006  0.080095  0.228070  0.193182
# 60803  1.000000  0.000024  0.017040  0.004446  0.128503  0.350877  0.380682
#
# ...

# %%
dfn.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.000000  0.000174  0.022238  0.010459  0.166631  0.543860  0.028409
# 1  0.000012  1.000000  0.004910  0.005757  0.117588  0.157895  0.193182
# 2  0.000036  1.000000  0.022094  0.004158  0.063291  0.508772  0.340909
# 3  0.000048  0.000107  0.022094  0.005706  0.149888  0.210526  0.193182
# 4  0.000059  0.000031  0.021083  0.004988  0.037516  0.228070  0.267045
#
#           7         8         9        10        11   12   13   14        15  \
# 0  0.342105  0.000000  0.028067  0.001111  0.000000  0.0  1.0  1.0  0.333333
# 1  0.105263  0.000000  0.026841  0.000861  0.000000  0.0  1.0  0.0  1.000000
# 2  0.118421  0.066667  0.004637  0.000156  0.166667  0.0  1.0  1.0  1.000000
# 3  0.105263  0.066667  0.013787  0.000715  0.166667  0.0  1.0  1.0  1.000000
# 4  0.078947  0.000000  0.026807  0.000705  0.000000  0.0  1.0  1.0  0.333333
#
#          16   17
# 0  0.200000  0.6
# 1  0.200000  0.6
# ...

# %%
dfn.rename(columns{"0" : "loanid","1" : "CurrentLoanAmount","2" : "CreditScore","3" : "AnnualIncome","4" : "MonthlyDebt","5" : "YearsofCreditHistory","6" : "Monthssincelastdelinquent","7" : "NumberofOpenAccounts","8" : "NumberofCreditProblems","9" : "CurrentCreditBalance","10" : "MaximumOpenCredit","11" : "Bankruptcies","12" : "TaxLiens","13" : "LoanStatus","14" : "term","15" : "homeownership","16" : "purpose","17" : "Yearsincurrentjobf"})
# Out:
#   File "<ipython-input-377-1f0e65a6397a>", line 1
#     dfn.rename(columns{"0" : "loanid","1" : "CurrentLoanAmount","2" : "CreditScore","3" : "AnnualIncome","4" : "MonthlyDebt","5" : "YearsofCreditHistory","6" : "Monthssincelastdelinquent","7" : "NumberofOpenAccounts","8" : "NumberofCreditProblems","9" : "CurrentCreditBalance","10" : "MaximumOpenCredit","11" : "Bankruptcies","12" : "TaxLiens","13" : "LoanStatus","14" : "term","15" : "homeownership","16" : "purpose","17" : "Yearsincurrentjobf"})
#                       ^
# SyntaxError: invalid syntax
